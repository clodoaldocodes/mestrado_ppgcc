# %%
from ultralytics import YOLO
import cv2
import os
import torch
import numpy as np
from ultralytics.utils.plotting import Annotator

# %%
path_type = "gray_850" 
# q6 - 450 - 560 - 685  (rgb_q6)
# q4 - 430 - 550 - 650  (rgb_q4)
# gray_650
# gray_850

img_path = "/home/clodoaldo/Documentos/non_HLB/" + path_type + "/"
output_path = "/home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/"
confidence_number = 0.3

#name_model = "yolov8n"
name_model = "yolov8x"
model = YOLO(name_model + ".pt")

output_path = output_path + name_model + "/"

file_names = [f for f in os.listdir(img_path) if os.path.isfile(os.path.join(img_path, f))]

selected_names = file_names[::10]

# %%
if not os.path.exists(output_path):
    os.makedirs(output_path)

for i in range(np.size(selected_names)):
    results = model.predict(img_path + selected_names[i])

    # Carregar a imagem
    img = cv2.imread(img_path+  selected_names[i])

    for result in results:
        # Obter informações sobre os boxes e probabilidades
        boxes = result.boxes.xyxy
        confidences = result.boxes.conf
        class_labels = result.boxes.cls

        # Iterar sobre os boxes
        for box, confidence, class_label in zip(boxes, confidences, class_labels):
            # Verificar se a confiança é maior que 0.5
            if confidence > confidence_number:
                # Extrair coordenadas do box
                x_min, y_min, x_max, y_max = map(int, box)

                # Desenhar o box na imagem
                color = (0, 255, 0)  # Cor verde
                thickness = 2
                cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color, thickness)

                # Adicionar rótulo com a classe e confiança
                class_name = classes[int(class_label)+1]
                label = f"Class: {class_name} - {int(class_label)+1}, Confidence: {confidence:.2f}"
                cv2.putText(img, label, (x_min, y_min - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, thickness)
    
    output_path_end = output_path + "output_" + str(i) + "_cf_" + str(confidence_number) + "_" + name_model + "_" + path_type + ".png"
    # Salvar a imagem com os boxes desenhados
    cv2.imwrite(output_path_end, img)
    print(f"Imagem salva em: {output_path_end}")
# Out:
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05789.ARW_stack.png: 640x640 1 apple, 6 oranges, 1171.9ms
# Speed: 4.9ms preprocess, 1171.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_0_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06639.ARW_stack.png: 640x640 (no detections), 1174.4ms
# Speed: 5.5ms preprocess, 1174.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_1_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06120.ARW_stack.png: 640x640 (no detections), 1172.4ms
# Speed: 6.1ms preprocess, 1172.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_2_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06308.ARW_stack.png: 640x640 1 potted plant, 1173.0ms
# Speed: 5.0ms preprocess, 1173.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_3_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06313.ARW_stack.png: 640x640 (no detections), 1173.1ms
# Speed: 4.3ms preprocess, 1173.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_4_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06088.ARW_stack.png: 640x640 (no detections), 1172.4ms
# Speed: 4.5ms preprocess, 1172.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_5_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06646.ARW_stack.png: 640x640 (no detections), 1172.6ms
# Speed: 4.4ms preprocess, 1172.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_6_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05667.ARW_stack.png: 640x640 (no detections), 1174.8ms
# Speed: 4.6ms preprocess, 1174.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_7_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05779.ARW_stack.png: 640x640 (no detections), 1172.5ms
# Speed: 5.9ms preprocess, 1172.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_8_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06575.ARW_stack.png: 640x640 (no detections), 1174.5ms
# Speed: 11.5ms preprocess, 1174.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_9_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06643.ARW_stack.png: 640x640 3 oranges, 1173.2ms
# Speed: 4.8ms preprocess, 1173.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_10_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06258.ARW_stack.png: 640x640 7 apples, 1173.4ms
# Speed: 4.7ms preprocess, 1173.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_11_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05751.ARW_stack.png: 640x640 1 apple, 6 oranges, 1171.0ms
# Speed: 4.3ms preprocess, 1171.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_12_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06679.ARW_stack.png: 640x640 (no detections), 1172.6ms
# Speed: 4.6ms preprocess, 1172.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_13_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05745.ARW_stack.png: 640x640 2 apples, 2 oranges, 1170.8ms
# Speed: 4.3ms preprocess, 1170.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_14_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05753.ARW_stack.png: 640x640 4 apples, 9 oranges, 1172.3ms
# Speed: 4.9ms preprocess, 1172.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_15_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05707.ARW_stack.png: 640x640 1 potted plant, 1 vase, 1173.4ms
# Speed: 4.7ms preprocess, 1173.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_16_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06097.ARW_stack.png: 640x640 3 oranges, 1 potted plant, 1172.2ms
# Speed: 4.3ms preprocess, 1172.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_17_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06226.ARW_stack.png: 640x640 1 orange, 1 potted plant, 1171.9ms
# Speed: 4.7ms preprocess, 1171.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_18_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05776.ARW_stack.png: 640x640 (no detections), 1173.6ms
# Speed: 4.6ms preprocess, 1173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_19_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06616.ARW_stack.png: 640x640 1 potted plant, 1172.6ms
# Speed: 4.4ms preprocess, 1172.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_20_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05717.ARW_stack.png: 640x640 2 apples, 1 orange, 1174.3ms
# Speed: 4.5ms preprocess, 1174.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_21_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06236.ARW_stack.png: 640x640 (no detections), 1171.1ms
# Speed: 4.4ms preprocess, 1171.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_22_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05773.ARW_stack.png: 640x640 (no detections), 1172.4ms
# Speed: 4.3ms preprocess, 1172.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_23_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06698.ARW_stack.png: 640x640 (no detections), 1173.6ms
# Speed: 4.5ms preprocess, 1173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_24_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06239.ARW_stack.png: 640x640 (no detections), 1173.8ms
# Speed: 4.7ms preprocess, 1173.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_25_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06554.ARW_stack.png: 640x640 (no detections), 1171.6ms
# Speed: 4.3ms preprocess, 1171.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_26_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06611.ARW_stack.png: 640x640 (no detections), 1173.3ms
# Speed: 4.5ms preprocess, 1173.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_27_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06079.ARW_stack.png: 640x640 (no detections), 1173.1ms
# Speed: 4.5ms preprocess, 1173.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_28_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06668.ARW_stack.png: 640x640 (no detections), 1172.0ms
# Speed: 5.0ms preprocess, 1172.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_29_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06244.ARW_stack.png: 640x640 (no detections), 1171.9ms
# Speed: 4.3ms preprocess, 1171.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_30_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06693.ARW_stack.png: 640x640 1 person, 1171.3ms
# Speed: 4.4ms preprocess, 1171.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_31_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05791.ARW_stack.png: 640x640 1 apple, 2 oranges, 1172.1ms
# Speed: 4.5ms preprocess, 1172.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_32_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05736.ARW_stack.png: 640x640 1 orange, 1171.4ms
# Speed: 4.7ms preprocess, 1171.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_33_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06701.ARW_stack.png: 640x640 1 apple, 1171.2ms
# Speed: 4.4ms preprocess, 1171.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_34_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06649.ARW_stack.png: 640x640 1 potted plant, 1170.7ms
# Speed: 5.2ms preprocess, 1170.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_35_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06263.ARW_stack.png: 640x640 (no detections), 1170.9ms
# Speed: 4.5ms preprocess, 1170.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_36_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06067.ARW_stack.png: 640x640 (no detections), 1172.9ms
# Speed: 5.6ms preprocess, 1172.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_37_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06102.ARW_stack.png: 640x640 3 oranges, 1 vase, 1172.4ms
# Speed: 4.6ms preprocess, 1172.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_38_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05706.ARW_stack.png: 640x640 1 tv, 1173.3ms
# Speed: 4.5ms preprocess, 1173.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_39_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05663.ARW_stack.png: 640x640 1 motorcycle, 1171.4ms
# Speed: 5.9ms preprocess, 1171.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_40_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05708.ARW_stack.png: 640x640 1 tv, 1172.6ms
# Speed: 4.5ms preprocess, 1172.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_41_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET06568.ARW_stack.png: 640x640 (no detections), 1172.4ms
# Speed: 5.9ms preprocess, 1172.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_42_cf_0.3_yolov8x_gray_850.png
#
# image 1/1 /home/clodoaldo/Documentos/non_HLB/gray_850/LET05762.ARW_stack.png: 640x640 (no detections), 1174.3ms
# Speed: 4.6ms preprocess, 1174.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagem salva em: /home/clodoaldo/Documentos/GitHub/mestrado_ppgcc/yolo_test/output/yolov8x/output_43_cf_0.3_yolov8x_gray_850.png

# %%
classes = {0: u'__background__',
 1: u'person',
 2: u'bicycle',
 3: u'car',
 4: u'motorcycle',
 5: u'airplane',
 6: u'bus',
 7: u'train',
 8: u'truck',
 9: u'boat',
 10: u'traffic light',
 11: u'fire hydrant',
 12: u'stop sign',
 13: u'parking meter',
 14: u'bench',
 15: u'bird',
 16: u'cat',
 17: u'dog',
 18: u'horse',
 19: u'sheep',
 20: u'cow',
 21: u'elephant',
 22: u'bear',
 23: u'zebra',
 24: u'giraffe',
 25: u'backpack',
 26: u'umbrella',
 27: u'handbag',
 28: u'tie',
 29: u'suitcase',
 30: u'frisbee',
 31: u'skis',
 32: u'snowboard',
 33: u'sports ball',
 34: u'kite',
 35: u'baseball bat',
 36: u'baseball glove',
 37: u'skateboard',
 38: u'surfboard',
 39: u'tennis racket',
 40: u'bottle',
 41: u'wine glass',
 42: u'cup',
 43: u'fork',
 44: u'knife',
 45: u'spoon',
 46: u'bowl',
 47: u'banana',
 48: u'apple',
 49: u'sandwich',
 50: u'orange',
 51: u'broccoli',
 52: u'carrot',
 53: u'hot dog',
 54: u'pizza',
 55: u'donut',
 56: u'cake',
 57: u'chair',
 58: u'couch',
 59: u'potted plant',
 60: u'bed',
 61: u'dining table',
 62: u'toilet',
 63: u'tv',
 64: u'laptop',
 65: u'mouse',
 66: u'remote',
 67: u'keyboard',
 68: u'cell phone',
 69: u'microwave',
 70: u'oven',
 71: u'toaster',
 72: u'sink',
 73: u'refrigerator',
 74: u'book',
 75: u'clock',
 76: u'vase',
 77: u'scissors',
 78: u'teddy bear',
 79: u'hair drier',
 80: u'toothbrush'}
